# %%
import meilisearch

client = meilisearch.Client('http://localhost:7700', 'rmuds5OuiWit9ccjQdTnjOUG3zvKi-ayIwunj3R0ums')
client.delete_index('Buddhism')
# Out:
# TaskInfo(task_uid=15, index_uid='Buddhism', status='enqueued', type='indexDeletion', enqueued_at=datetime.datetime(2025, 4, 6, 8, 23, 54, 590300))
